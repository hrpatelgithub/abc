# %%
import pandas as pd

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#covert into readable  formate foor get data
import requests

# %%
data = requests.get(url)

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51424',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51424/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51424/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51424/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51424',
#   'id': 1586922483,
#   'node_id': 'I_kwDOAA0YD85eloPz',
#   'number': 51424,
#   'title': 'API: quantile with bool/boolean dtypes',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
df=pd.DataFrame(data1,columns=['user'])
df
# Out:
#                                                  user
# 0   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1   {'login': 'luke396', 'id': 77875500, 'node_id'...
# 2   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 3   {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 4   {'login': 'mvashishtha', 'id': 10712109, 'node...
# 5   {'login': 'topper-123', 'id': 26364415, 'node_...
# 6   {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 7   {'login': 'noatamir', 'id': 6564007, 'node_id'...
# 8   {'login': 'jorisvandenbossche', 'id': 1020496,...
# 9   {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 10  {'login': 'juleek', 'id': 10097788, 'node_id':...
# 11  {'login': 'topper-123', 'id': 26364415, 'node_...
# 12  {'login': 'phofl', 'id': 61934744, 'node_id': ...
# 13  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 14  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 15  {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# ...

# %%
df.to_csv("user.csv")

# %% [markdown]
# # Question
# In above column data is in dictionary formate ,can i generate new column like login,id,node_id...... form above column
